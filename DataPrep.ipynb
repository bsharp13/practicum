# %%
import numpy as np
import pandas as pd
from dfply import *

# %%
appointment = pd.read_csv('appointments.csv')

# %%
appointment.head(100)
# Out:
#        PatientId  AppointmentID Gender          ScheduledDay  \
# 0   2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1   5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2   4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3   8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4   8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5   9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6   7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7   3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8   5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9   7.812456e+13        5629123      F  2016-04-27T12:48:25Z
# 10  7.345362e+14        5630213      F  2016-04-27T14:58:11Z
# 11  7.542951e+12        5620163      M  2016-04-26T08:44:12Z
# 12  5.666548e+14        5634718      F  2016-04-28T11:33:51Z
# 13  9.113946e+14        5636249      M  2016-04-28T14:52:07Z
# ...

# %%
appointment['Gender'] = np.where(appointment['Gender'] == 'F', 0, 1)
appointment['ScheduledDay'] = pd.to_datetime(appointment['ScheduledDay']).dt.date
appointment['AppointmentDay'] = pd.to_datetime(appointment['AppointmentDay']).dt.date
appointment['DaysBetween'] = abs(
    appointment['ScheduledDay'] - appointment['AppointmentDay']
).dt.days
appointment['NoShow'] = np.where(appointment['No-show'] == 'No', 0, 1)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1167: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-33b877b40467> in <module>
# ----> 1 appointment['Gender'] = np.where(appointment['Gender'] == 'F', 0, 1)
#       2 appointment['ScheduledDay'] = pd.to_datetime(appointment['ScheduledDay']).dt.date
#       3 appointment['AppointmentDay'] = pd.to_datetime(appointment['AppointmentDay']).dt.date
#       4 appointment['DaysBetween'] = abs(
#       5     appointment['ScheduledDay'] - appointment['AppointmentDay']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# ...

# %%
appointment = (appointment >> 
    arrange(X.PatientId, X.AppointmentDay) >>
    group_by(X.PatientId) >>
    mutate(
        PreviousMiss = cumsum(X.NoShow)
    )
)

# %%
appointment.to_csv('appointments_clean.csv')
